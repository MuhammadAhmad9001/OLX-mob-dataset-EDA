# %% [markdown]
# # Introduction :-
#
#             In this project of my Data Analysis, I am investigating a TMDb movies database file which has collection of
#        important detials of about 10k+ movies, including their details of budget, revenue, release dates
#
# # Data cleaning :-
#                     There is some setps for data cleanng
#              1:- Like remove NAN values
#              2:- Remove duplicaation values
#              3:- Remove 0 values
#              4:- Remove column of columns that are not useful
# # Deep Anaylsis :-
#                           In deep thinking we have some of the serach Question from the dataset
#                           that create useful info from dataset
#              1:- Which movie had the greatest and least revenue?
#              2:- Which genre were more successful?

# %% [markdown]
# # Import library pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading data set

# %%
df = pd.read_csv('D:/tmdb-movies.csv')
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                                 homepage            director  \
# 0                          http://www.jurassicworld.com/     Colin Trevorrow
# 1                            http://www.madmaxmovie.com/       George Miller
# 2         http://www.thedivergentseries.movie/#insurgent    Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...         J.J. Abrams
# 4                               http://www.furious7.com/           James Wan
# ...                                                  ...                 ...
# 10861                                                NaN         Bruce Brown
# 10862                                                NaN  John Frankenheimer
# 10863                                                NaN      Eldar Ryazanov
# 10864                                                NaN         Woody Allen
# 10865                                                NaN    Harold P. Warren
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10861                                                NaN  ...
# 10862  Cinerama sweeps YOU into a drama of speed and ...  ...
# 10863                                                NaN  ...
# 10864                          WOODY ALLEN STRIKES BACK!  ...
# 10865       It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10861  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1      Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2      Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3              Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4      Universal Pictures|Original Film|Media Rights ...       4/1/15
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films      6/15/66
# 10862  Cherokee Productions|Joel Productions|Douglas ...     12/21/66
# 10863                                            Mosfilm       1/1/66
# 10864                            Benedict Pictures Corp.      11/2/66
# 10865                                          Norm-Iris     11/15/66
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10861         11           7.4          1966  0.000000e+00  0.000000e+00
# 10862         20           5.7          1966  0.000000e+00  0.000000e+00
# 10863         11           6.5          1966  0.000000e+00  0.000000e+00
# 10864         22           5.4          1966  0.000000e+00  0.000000e+00
# 10865         15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 21 columns]

# %% [markdown]
# # Checking data columns names

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# # Data cleaning
#
# Now before going deep into we should clean some data . First we check that data with zero values then duplication or Nan values.
#
# First, lets clean up the columns. We will only keep the columns we need and remove the rest of them.
#
# Columns to delete - id, imdb_id, popularity, budget_adj, revenue_adj, homepage, keywords, overview, production_companies, vote_count and vote_average.

# %% [markdown]
# # Checking null values

# %%
miss = df.isnull().sum()
miss[0:10]
# Out:
# id                   0
# imdb_id             10
# popularity           0
# budget               0
# revenue              0
# original_title       0
# cast                76
# homepage          7930
# director            44
# tagline           2824
# dtype: int64

# %% [markdown]
# # Droping NAN values

# %%
df.dropna(inplace=True)

# %%
miss = df.isnull().sum()
miss[0:10]
# Out:
# id                0
# imdb_id           0
# popularity        0
# budget            0
# revenue           0
# original_title    0
# cast              0
# homepage          0
# director          0
# tagline           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1992 non-null   int64
#  1   imdb_id               1992 non-null   object
#  2   popularity            1992 non-null   float64
#  3   budget                1992 non-null   int64
#  4   revenue               1992 non-null   int64
#  5   original_title        1992 non-null   object
#  6   cast                  1992 non-null   object
#  7   homepage              1992 non-null   object
#  8   director              1992 non-null   object
#  9   tagline               1992 non-null   object
#  10  keywords              1992 non-null   object
#  11  overview              1992 non-null   object
#  12  runtime               1992 non-null   int64
#  13  genres                1992 non-null   object
#  14  production_companies  1992 non-null   object
#  15  release_date          1992 non-null   object
#  16  vote_count            1992 non-null   int64
#  17  vote_average          1992 non-null   float64
#  18  release_year          1992 non-null   int64
#  19  budget_adj            1992 non-null   float64
#  20  revenue_adj           1992 non-null   float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 342.4+ KB

# %% [markdown]
# # Checking duplicated values if any.

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10724    False
# 10759    False
# 10760    False
# 10817    False
# 10819    False
# Length: 1992, dtype: bool

# %% [markdown]
# # Deleting col from dataset

# %%
del_col = ['id','imdb_id','homepage','tagline','runtime','keywords']
df = df.drop(del_col,1)

# %%
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview  \
# 0  Twenty-two years after the events of Jurassic ...
# 1  An apocalyptic story set in the furthest reach...
# 2  Beatrice Prior must confront her inner demons ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %% [markdown]
# # After cleaning
#
#  setting date types,sorting, arranging dataset

# %% [markdown]
# # Setting dateset index

# %%
df.set_index('release_date')
# Out:
#                   id    imdb_id  popularity     budget     revenue  \
# release_date
# 6/9/15        135397  tt0369610   32.985763  150000000  1513528810
# 5/13/15        76341  tt1392190   28.419936  150000000   378436354
# 3/18/15       262500  tt2908446   13.112507  110000000   295238201
# 12/15/15      140607  tt2488496   11.173104  200000000  2068178225
# 4/1/15        168259  tt2820852    9.335014  190000000  1506249360
# ...              ...        ...         ...        ...         ...
# 12/12/69         668  tt0064757    1.778746    7000000    81974493
# 10/25/78         948  tt0077651    1.198849     300000    70000000
# 7/27/78         8469  tt0077975    1.157930    2700000   141000000
# 5/1/78         13963  tt0077838    0.064029          0      321952
# 7/28/78        16214  tt0077696    0.044675          0    78000000
#
#                                original_title  \
# release_date
# 6/9/15                         Jurassic World
# 5/13/15                    Mad Max: Fury Road
# 3/18/15                             Insurgent
# 12/15/15         Star Wars: The Force Awakens
# 4/1/15                              Furious 7
# ...                                       ...
# 12/12/69      On Her Majesty's Secret Service
# 10/25/78                            Halloween
# 7/27/78                          Animal House
# 5/1/78                         The Last Waltz
# 7/28/78                                Hooper
#
#                                                            cast  \
# release_date
# 6/9/15        Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 5/13/15       Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 3/18/15       Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 12/15/15      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4/1/15        Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                         ...
# 12/12/69      George Lazenby|Diana Rigg|Telly Savalas|Gabrie...
# 10/25/78      Donald Pleasence|Jamie Lee Curtis|P.J. Soles|N...
# 7/27/78       John Belushi|Tim Matheson|John Vernon|Verna Bl...
# 5/1/78        Robbie Robertson|Rick Danko|Levon Helm|Richard...
# 7/28/78       Burt Reynolds|Robert Klein|Adam West|Jan-Micha...
#
#                                                        homepage  \
# release_date
# 6/9/15                            http://www.jurassicworld.com/
# 5/13/15                             http://www.madmaxmovie.com/
# 3/18/15          http://www.thedivergentseries.movie/#insurgent
# 12/15/15      http://www.starwars.com/films/star-wars-episod...
# 4/1/15                                 http://www.furious7.com/
# ...                                                         ...
# 12/12/69      http://www.mgm.com/view/movie/1411/On-Her-Maje...
# 10/25/78      http://www.theofficialjohncarpenter.com/hallow...
# 7/27/78                             http://www.animalhouse.com/
# 5/1/78        http://www.mgm.com/#/our-titles/1092/The-Last-...
# 7/28/78              http://en.wikipedia.org/wiki/Hooper_(film)
#
#                       director  \
# release_date
# 6/9/15         Colin Trevorrow
# 5/13/15          George Miller
# 3/18/15       Robert Schwentke
# 12/15/15           J.J. Abrams
# 4/1/15               James Wan
# ...                        ...
# 12/12/69         Peter R. Hunt
# 10/25/78        John Carpenter
# 7/27/78            John Landis
# 5/1/78         Martin Scorsese
# 7/28/78            Hal Needham
#
#                                                         tagline  \
# release_date
# 6/9/15                                        The park is open.
# 5/13/15                                      What a Lovely Day.
# 3/18/15                              One Choice Can Destroy You
# 12/15/15                          Every generation has a story.
# 4/1/15                                      Vengeance Hits Home
# ...                                                         ...
# 12/12/69      Far up! Far out! Far more! James Bond 007 is b...
# 10/25/78                                The Night HE Came Home!
# 7/27/78       It was the Deltas against the rules... the rul...
# 5/1/78        It Started as a Concert. It Became a Celebration.
# 7/28/78                            The greatest stuntman alive!
#
#                                                        keywords  \
# release_date
# 6/9/15        monster|dna|tyrannosaurus rex|velociraptor|island
# 5/13/15        future|chase|post-apocalyptic|dystopia|australia
# 3/18/15       based on novel|revolution|dystopia|sequel|dyst...
# 12/15/15                  android|spaceship|jedi|space opera|3d
# 4/1/15                      car race|speed|revenge|suspense|car
# ...                                                         ...
# 12/12/69      london|suicide|england|switzerland|secret iden...
# 10/25/78         female nudity|nudity|mask|babysitter|halloween
# 7/27/78             female nudity|sex|nudity|collage|fraternity
# 5/1/78                                              1970s|music
# 7/28/78                                      stuntman|hollywood
#
#                                                        overview  runtime  \
# release_date
# 6/9/15        Twenty-two years after the events of Jurassic ...      124
# 5/13/15       An apocalyptic story set in the furthest reach...      120
# 3/18/15       Beatrice Prior must confront her inner demons ...      119
# 12/15/15      Thirty years after defeating the Galactic Empi...      136
# 4/1/15        Deckard Shaw seeks revenge against Dominic Tor...      137
# ...                                                         ...      ...
# 12/12/69      James Bond tracks archnemesis Ernst Blofeld to...      142
# 10/25/78      A psychotic murderer, institutionalized since ...       91
# 7/27/78       At a 1962 College, Dean Vernon Wormer is deter...      109
# 5/1/78        Martin Scorsese's rockumentary intertwines foo...      117
# 7/28/78       Burt Reynolds plays a legendary stunt man know...      107
#
#                                                  genres  \
# release_date
# 6/9/15        Action|Adventure|Science Fiction|Thriller
# 5/13/15       Action|Adventure|Science Fiction|Thriller
# 3/18/15              Adventure|Science Fiction|Thriller
# 12/15/15       Action|Adventure|Science Fiction|Fantasy
# 4/1/15                            Action|Crime|Thriller
# ...                                                 ...
# 12/12/69                      Adventure|Action|Thriller
# 10/25/78                                Horror|Thriller
# 7/27/78                                          Comedy
# 5/1/78                                Documentary|Music
# 7/28/78                                   Action|Comedy
#
#                                            production_companies  vote_count  \
# release_date
# 6/9/15        Universal Studios|Amblin Entertainment|Legenda...        5562
# 5/13/15       Village Roadshow Pictures|Kennedy Miller Produ...        6185
# 3/18/15       Summit Entertainment|Mandeville Films|Red Wago...        2480
# 12/15/15              Lucasfilm|Truenorth Productions|Bad Robot        5292
# 4/1/15        Universal Pictures|Original Film|Media Rights ...        2947
# ...                                                         ...         ...
# 12/12/69       Eon Productions|Metro-Goldwyn-Mayer (MGM)|Danjaq         258
# 10/25/78      Compass International Pictures|Falcon Internat...         522
# 7/27/78       Universal Pictures|Oregon Film Factory|Stage I...         230
# 5/1/78                           FM Productions|Last Waltz Inc.          33
# 7/28/78                                            Warner Bros.          13
#
#               vote_average  release_year    budget_adj   revenue_adj
# release_date
# 6/9/15                 6.5          2015  1.379999e+08  1.392446e+09
# 5/13/15                7.1          2015  1.379999e+08  3.481613e+08
# 3/18/15                6.3          2015  1.012000e+08  2.716190e+08
# 12/15/15               7.5          2015  1.839999e+08  1.902723e+09
# 4/1/15                 7.3          2015  1.747999e+08  1.385749e+09
# ...                    ...           ...           ...           ...
# 12/12/69               6.4          1969  4.160985e+07  4.872780e+08
# 10/25/78               7.3          1978  1.002810e+06  2.339890e+08
# 7/27/78                6.7          1978  9.025292e+06  4.713208e+08
# 5/1/78                 8.0          1978  0.000000e+00  1.076189e+06
# 7/28/78                6.0          1978  0.000000e+00  2.607307e+08
#
# [1992 rows x 20 columns]

# %% [markdown]
# # checking data types

# %%
df.dtypes
# Out:
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# director                 object
# overview                 object
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
df.rename(columns = {'budget' : 'budget_(in_US-Dollars)', 'revenue' : 'revenue_(in_US-Dollars)'}, inplace = True)

# %%
change_coltype = ['budget', 'revenue']

df[change_coltype] = df[change_coltype].applymap(np.int64)

df.head()
# Out:
#    popularity  budget_(in_US-Dollars)  revenue_(in_US-Dollars)  \
# 0   32.985763               150000000               1513528810
# 1   28.419936               150000000                378436354
# 2   13.112507               110000000                295238201
# 3   11.173104               200000000               2068178225
# 4    9.335014               190000000               1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview  \
# 0  Twenty-two years after the events of Jurassic ...
# 1  An apocalyptic story set in the furthest reach...
# 2  Beatrice Prior must confront her inner demons ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %%
df.release_date = pd.to_datetime(df['release_date'])

df.head(2)
# Out:
#    popularity  budget_(in_US-Dollars)  profit_(in_US_Dollars)  \
# 0   32.985763               150000000              1363528810
# 1   28.419936               150000000               228436354
#
#    revenue_(in_US-Dollars)      original_title  \
# 0               1513528810      Jurassic World
# 1                378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#                                             overview  \
# 0  Twenty-two years after the events of Jurassic ...
# 1  An apocalyptic story set in the furthest reach...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13        6185
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08

# %%
#assigning a new column which will hold the profit values of each movie

#the insert function's first argument is an index number given to locate the column, second argument takes the name of the new column...
#...and last but not least it takes the calculation values to output for specific column

#To calculate profit of each movie, we need to substract the budget from the revenue of each movie

df.insert(2, 'profit_(in_US_Dollars)', df['revenue_(in_US-Dollars)'] - df['budget_(in_US-Dollars)'])

# %%
import numpy as np

df['profit_(in_US_Dollars)'] = df['profit_(in_US_Dollars)'].apply(np.int64)
df.head()
# Out:
#    popularity  budget_(in_US-Dollars)  profit_(in_US_Dollars)  \
# 0   32.985763               150000000              1363528810
# 1   28.419936               150000000               228436354
# 2   13.112507               110000000               185238201
# 3   11.173104               200000000              1868178225
# 4    9.335014               190000000              1316249360
#
#    revenue_(in_US-Dollars)                original_title  \
# 0               1513528810                Jurassic World
# 1                378436354            Mad Max: Fury Road
# 2                295238201                     Insurgent
# 3               2068178225  Star Wars: The Force Awakens
# 4               1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview  \
# 0  Twenty-two years after the events of Jurassic ...
# 1  An apocalyptic story set in the furthest reach...
# 2  Beatrice Prior must confront her inner demons ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %% [markdown]
# # Search Question
#
# # Q 1
#
# # Which movie earns the most and least profit?

# %% [markdown]
#
# def highest_lowest(column_name):
#
#     #highest
#     highest_id = df[column_name].idxmax()
#     highest_details = pd.DataFrame(df.loc[highest_id])
#
#     #lowest
#     lowest_id = df[column_name].idxmin()
#     lowest_details = pd.DataFrame(df.loc[lowest_id])
#
#     #concatenating two dataset
#     two_in_one_data = pd.concat([highest_details, lowest_details], axis = 1)
#
#     return two_in_one_data
#
# #calling the function and passing the argument
# highest_lowest('profit_(in_US_Dollars)')

# %%
# Which movie had the greatest and least budget?

highest_lowest('budget_(in_US-Dollars)')
# Out:
#                                                                       2244  \
# popularity                                                         0.25054
# budget_(in_US-Dollars)                                           425000000
# profit_(in_US_Dollars)                                          -413912431
# revenue_(in_US-Dollars)                                           11087569
# original_title                                           The Warrior's Way
# cast                     Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                        Sngmoo Lee
# overview                 An Asian assassin (Dong-gun Jang) is forced to...
# genres                           Adventure|Fantasy|Action|Western|Thriller
# production_companies                              Boram Entertainment Inc.
# release_date                                           2010-12-02 00:00:00
# vote_count                                                              74
# vote_average                                                           6.4
# release_year                                                          2010
# budget_adj                                                        4.25e+08
# revenue_adj                                                    1.10876e+07
#
#                                                                       30
# popularity                                                         3.92733
# budget_(in_US-Dollars)                                                   0
# profit_(in_US_Dollars)                                            29355203
# revenue_(in_US-Dollars)                                           29355203
# original_title                                                  Mr. Holmes
# cast                     Ian McKellen|Milo Parker|Laura Linney|Hattie M...
# director                                                       Bill Condon
# overview                 The story is set in 1947, following a long-ret...
# genres                                                       Mystery|Drama
# production_companies     BBC Films|See-Saw Films|FilmNation Entertainme...
# release_date                                           2015-06-19 00:00:00
# vote_count                                                             425
# vote_average                                                           6.4
# release_year                                                          2015
# budget_adj                                                               0
# revenue_adj                                                    2.70068e+07

# %% [markdown]
# # Search Question
#
# # Q 2
#
# # Which movie had the greatest and least revenue?

# %%
highest_lowest('revenue_(in_US-Dollars)')
# Out:
#                                                                       1386  \
# popularity                                                         9.43277
# budget_(in_US-Dollars)                                           237000000
# profit_(in_US_Dollars)                                          2544505847
# revenue_(in_US-Dollars)                                         2781505847
# original_title                                                      Avatar
# cast                     Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                     James Cameron
# overview                 In the 22nd century, a paraplegic Marine is di...
# genres                            Action|Adventure|Fantasy|Science Fiction
# production_companies     Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                           2009-12-10 00:00:00
# vote_count                                                            8458
# vote_average                                                           7.1
# release_year                                                          2009
# budget_adj                                                     2.40887e+08
# revenue_adj                                                    2.82712e+09
#
#                                                                       67
# popularity                                                         2.33164
# budget_(in_US-Dollars)                                            20000000
# profit_(in_US_Dollars)                                           -20000000
# revenue_(in_US-Dollars)                                                  0
# original_title                                                    Survivor
# cast                     Pierce Brosnan|Milla Jovovich|Dylan McDermott|...
# director                                                    James McTeigue
# overview                 A Foreign Service Officer in London tries to p...
# genres                                               Crime|Thriller|Action
# production_companies     Nu Image Films|Winkler Films|Millennium Films|...
# release_date                                           2015-05-21 00:00:00
# vote_count                                                             280
# vote_average                                                           5.4
# release_year                                                          2015
# budget_adj                                                        1.84e+07
# revenue_adj                                                              0

# %%
from matplotlib import pyplot as plt

# In which year we had the most movies making profits?
#giving the figure size(width, height)
#labeling x-axis
#labeling y-axis
#title of a the plot

profits_each_year = df.groupby('release_year')['profit_(in_US_Dollars)'].sum()
plt.figure(figsize=(12,6), dpi = 130)
plt.xlabel('Release Year of Movies', fontsize = 12)
plt.ylabel('Total Profits made by Movies', fontsize = 12)
plt.title('Calculating Total Profits made by all movies in year which it released.')

#plotting what needs to be plotted
#showing the plot

plt.plot(profits_each_year)
plt.show()

# %%
#assinging new dataframe which holds values only of movies having profit $50M or more
profit_movie_data = df[df['profit_(in_US_Dollars)'] >= 50000000]

#reindexing new dataframe
profit_movie_data.index = range(len(profit_movie_data))
#will initialize dataframe from 1 instead of 0
profit_movie_data.index = profit_movie_data.index + 1

#showing the dataset
profit_movie_data.head(2)
# Out:
#    popularity  budget_(in_US-Dollars)  profit_(in_US_Dollars)  \
# 1   32.985763               150000000              1363528810
# 2   28.419936               150000000               228436354
#
#    revenue_(in_US-Dollars)      original_title  \
# 1               1513528810      Jurassic World
# 2                378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 1  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 2  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#                                             overview  \
# 1  Twenty-two years after the events of Jurassic ...
# 2  An apocalyptic story set in the furthest reach...
#
#                                       genres  \
# 1  Action|Adventure|Science Fiction|Thriller
# 2  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 1  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
# 2  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13        6185
#
#    vote_average  release_year    budget_adj   revenue_adj
# 1           6.5          2015  1.379999e+08  1.392446e+09
# 2           7.1          2015  1.379999e+08  3.481613e+08

# %%
#giving a new average function since we have a different dataset
def prof_avg_fuc(column_name):
    return profit_movie_data[column_name].mean()

# %%
#function which will take any column as argument from which data is need to be extracted and keep track of count
def extract_data(column_name):
    #will take a column, and separate the string by '|'
    all_data = profit_movie_data[column_name].str.cat(sep = '|')
    
    #giving pandas series and storing the values separately
    all_data = pd.Series(all_data.split('|'))
    
    #this will us value in descending order
    count = all_data.value_counts(ascending = False)
    
    return count

# %% [markdown]
# # 2 Q
#
#
# # Search Question
#
#
# # Which genre were more successful?

# %%
#this will variable will store the return value from a function
#shwoing top 5 values

genre_count = extract_data('genres')
genre_count.head()
# Out:
# Action       246
# Adventure    212
# Comedy       207
# Drama        198
# Thriller     177
# dtype: int64

# %%
#we want plot to plot points in descending order top to bottom 
#since our count is in descending order and graph plot points from bottom to top, our graph will be in ascending order form top to bottom 
#hence lets give the series in ascending order 
genre_count.sort_values(ascending = True, inplace = True)

#initializing plot 
ax = genre_count.plot.bar(color = '#007482', fontsize = 15)

#giving a title 
ax.set(title = 'The Most filmed genres')

#x-label 
ax.set_xlabel('Number of Movies', color = 'g', fontsize = '18')

#giving the figure size(width, height) 
ax.figure.set_size_inches(12, 10)

#shwoing the plot 
plt.show()

# %% [markdown]
# # Conclusion
#
# As i have answered the questions that i thought would be interesting to dig into,
# i want to wrap up all my findings in this way ....
#
# ## Q Which genre were more successful?
#
# #Ans. I would..
#
#     Comedy       492
#     Drama        481
#     Action       464
#     Thriller     405
#     Adventure    379
#
# Limitations:-
#             In this conclusion we have genre sucessful but this is limited movies with limited years so we not have lastest dataset that we use in cuurent analysis
#
#            And that's my conclusion!
